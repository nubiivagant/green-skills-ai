# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('green transportation system.csv')

# %%
df
# Out:
#       energy_efficiency  co2_emissions  electric_vehicle_penetration  \
# 0             17.490802     106.046123                     46.499916
# 1             29.014286      99.936814                     19.225600
# 2             24.639879      76.423087                     27.331985
# 3             21.973170     141.090001                     43.164032
# 4             13.120373     121.493624                     34.104467
# ...                 ...            ...                           ...
# 9995          27.153120     181.555794                     57.613773
# 9996          27.950177      57.022094                     47.391211
# 9997          28.934158      95.554770                     10.972793
# 9998          17.949760     116.498001                     30.050242
# 9999          14.342808      75.839722                     22.869899
#
#       cost_efficiency  public_transport_usage
# 0            2.095361               27.934722
# 1            1.648231               15.689067
# 2            2.911246               17.581553
# 3            1.047446               20.840268
# 4            1.969641               22.219200
# ...               ...                     ...
# 9995         2.385085               47.346712
# 9996         2.411317               23.571614
# 9997         1.173924               54.939705
# 9998         1.585799               41.260655
# 9999         1.718559               61.702403
#
# [10000 rows x 5 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split

# %%
X_train, X_test = train_test_split(df, test_size= 0.2, random_state=42)
sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

# %%
scaler = StandardScaler()
scaler.fit(df)
# Out:
# StandardScaler()

# %%
scaled_data = scaler.transform(df)

# %%
scaled_data.shape
# Out:
# (10000, 5)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)

# %%
pca.fit(scaled_data)
# Out:
# PCA(n_components=2)

# %%
X_new = pca.transform(scaled_data)
X_new.shape
# Out:
# (10000, 2)

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_new[:,0], X_new[:,1], c=df['cost_efficiency'], cmap='plasma')
plt.xlabel('First principal component')
plt.ylabel('Second principal component')
plt.show()
